# %%
# Dependencies and Setup
import pandas as pd
from pathlib import Path

# %%
# File to Load
JC_2016_tripdata = Path("Resources/JC-201606-citibike-tripdata.csv")
JC_2021_tripdata = Path("Resources/JC-202101-citibike-tripdata.csv")

# Read JC Data File and store into Pandas DataFrames
JC_2016_df = pd.read_csv(JC_2016_tripdata)
JC_2O21_df = pd.read_csv(JC_2021_tripdata)

# %%
# Display the data table for JC_2016
JC_2016_df
# Out:
#        Trip Duration           Start Time            Stop Time  \
# 0                669  2016-06-01 00:00:37  2016-06-01 00:11:46
# 1                945  2016-06-01 00:14:54  2016-06-01 00:30:40
# 2                334  2016-06-01 00:34:52  2016-06-01 00:40:26
# 3                473  2016-06-01 00:40:30  2016-06-01 00:48:23
# 4                551  2016-06-01 00:50:06  2016-06-01 00:59:17
# ...              ...                  ...                  ...
# 23942            183  2016-06-30 23:37:24  2016-06-30 23:40:27
# 23943            475  2016-06-30 23:38:50  2016-06-30 23:46:46
# 23944            246  2016-06-30 23:39:18  2016-06-30 23:43:25
# 23945            738  2016-06-30 23:39:41  2016-06-30 23:51:59
# 23946            298  2016-06-30 23:52:12  2016-06-30 23:57:11
#
#        Start Station ID Start Station Name  Start Station Latitude  \
# 0                  3186      Grove St PATH               40.719586
# 1                  3199       Newport Pkwy               40.728745
# ...

# %%
# Display the data table for JC_2O21
JC_2O21_df
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               266  2021-01-01 00:03:35.5100  2021-01-01 00:08:01.7770
# 1              1543  2021-01-01 00:23:32.9250  2021-01-01 00:49:16.0830
# 2              1461  2021-01-01 00:23:50.7940  2021-01-01 00:48:12.5660
# 3               793  2021-01-01 00:31:09.0770  2021-01-01 00:44:22.9430
# 4               596  2021-01-01 00:35:52.1900  2021-01-01 00:45:48.7740
# ...             ...                       ...                       ...
# 11619          2476  2021-01-31 20:16:05.4700  2021-01-31 20:57:22.0110
# 11620           147  2021-01-31 21:05:05.2090  2021-01-31 21:07:32.8660
# 11621           660  2021-01-31 21:06:23.5880  2021-01-31 21:17:23.8420
# 11622           384  2021-01-31 21:16:37.8220  2021-01-31 21:23:02.1240
# 11623           356  2021-01-31 23:24:50.8810  2021-01-31 23:30:47.3030
#
#        start station id start station name  start station latitude  \
# ...

# %%
# Rename columns for JC_2021
JC_2021_renamed_df = JC_2O21_df.rename(columns={"tripduration": "Trip Duration", "starttime": "Start Time",
                                                "stoptime": "Stop Time", "start station id": "Start Station ID",
                                               "start station name": "Start Station Name",
                                                "start station latitude": "Start Station Latitude", 
                                               "start station longitude": "Start Station Longitude",
                                               "end station id": "End Station ID",
                                                "end station name": "End Station Name",
                                               "end station latitude": "End Station Latitude",
                                               "end station longitude": "End Station Longitude",
                                               "bikeid": "Bike ID", "usertype": "User Type",
                                                "birth year": "Birth Year", "gender": "Gender"})
JC_2021_renamed_df
# Out:
#        Trip Duration                Start Time                 Stop Time  \
# 0                266  2021-01-01 00:03:35.5100  2021-01-01 00:08:01.7770
# 1               1543  2021-01-01 00:23:32.9250  2021-01-01 00:49:16.0830
# 2               1461  2021-01-01 00:23:50.7940  2021-01-01 00:48:12.5660
# 3                793  2021-01-01 00:31:09.0770  2021-01-01 00:44:22.9430
# 4                596  2021-01-01 00:35:52.1900  2021-01-01 00:45:48.7740
# ...              ...                       ...                       ...
# 11619           2476  2021-01-31 20:16:05.4700  2021-01-31 20:57:22.0110
# 11620            147  2021-01-31 21:05:05.2090  2021-01-31 21:07:32.8660
# 11621            660  2021-01-31 21:06:23.5880  2021-01-31 21:17:23.8420
# 11622            384  2021-01-31 21:16:37.8220  2021-01-31 21:23:02.1240
# 11623            356  2021-01-31 23:24:50.8810  2021-01-31 23:30:47.3030
#
#        Start Station ID Start Station Name  Start Station Latitude  \
# ...

# %%
# Combine DataFrames
JC_combined_df = pd.concat([JC_2016_df, JC_2021_renamed_df], axis=0, ignore_index=True)
JC_combined_df
# Out:
#        Trip Duration                Start Time                 Stop Time  \
# 0                669       2016-06-01 00:00:37       2016-06-01 00:11:46
# 1                945       2016-06-01 00:14:54       2016-06-01 00:30:40
# 2                334       2016-06-01 00:34:52       2016-06-01 00:40:26
# 3                473       2016-06-01 00:40:30       2016-06-01 00:48:23
# 4                551       2016-06-01 00:50:06       2016-06-01 00:59:17
# ...              ...                       ...                       ...
# 35566           2476  2021-01-31 20:16:05.4700  2021-01-31 20:57:22.0110
# 35567            147  2021-01-31 21:05:05.2090  2021-01-31 21:07:32.8660
# 35568            660  2021-01-31 21:06:23.5880  2021-01-31 21:17:23.8420
# 35569            384  2021-01-31 21:16:37.8220  2021-01-31 21:23:02.1240
# 35570            356  2021-01-31 23:24:50.8810  2021-01-31 23:30:47.3030
#
#        Start Station ID Start Station Name  Start Station Latitude  \
# ...

# %%
# Drop null values
JC_combined_cleaned_df = JC_combined_df.dropna(how="any")
JC_combined_cleaned_df
# Out:
#        Trip Duration                Start Time                 Stop Time  \
# 0                669       2016-06-01 00:00:37       2016-06-01 00:11:46
# 1                945       2016-06-01 00:14:54       2016-06-01 00:30:40
# 2                334       2016-06-01 00:34:52       2016-06-01 00:40:26
# 3                473       2016-06-01 00:40:30       2016-06-01 00:48:23
# 4                551       2016-06-01 00:50:06       2016-06-01 00:59:17
# ...              ...                       ...                       ...
# 35566           2476  2021-01-31 20:16:05.4700  2021-01-31 20:57:22.0110
# 35567            147  2021-01-31 21:05:05.2090  2021-01-31 21:07:32.8660
# 35568            660  2021-01-31 21:06:23.5880  2021-01-31 21:17:23.8420
# 35569            384  2021-01-31 21:16:37.8220  2021-01-31 21:23:02.1240
# 35570            356  2021-01-31 23:24:50.8810  2021-01-31 23:30:47.3030
#
#        Start Station ID Start Station Name  Start Station Latitude  \
# ...

# %%
# Drop rows with 0 for Gender
JC_cleaned_tripdata_df = JC_combined_cleaned_df.drop(JC_combined_cleaned_df[JC_combined_cleaned_df["Gender"] ==0].index)
JC_cleaned_tripdata_df
# Out:
#        Trip Duration                Start Time                 Stop Time  \
# 0                669       2016-06-01 00:00:37       2016-06-01 00:11:46
# 1                945       2016-06-01 00:14:54       2016-06-01 00:30:40
# 2                334       2016-06-01 00:34:52       2016-06-01 00:40:26
# 3                473       2016-06-01 00:40:30       2016-06-01 00:48:23
# 4                551       2016-06-01 00:50:06       2016-06-01 00:59:17
# ...              ...                       ...                       ...
# 35566           2476  2021-01-31 20:16:05.4700  2021-01-31 20:57:22.0110
# 35567            147  2021-01-31 21:05:05.2090  2021-01-31 21:07:32.8660
# 35568            660  2021-01-31 21:06:23.5880  2021-01-31 21:17:23.8420
# 35569            384  2021-01-31 21:16:37.8220  2021-01-31 21:23:02.1240
# 35570            356  2021-01-31 23:24:50.8810  2021-01-31 23:30:47.3030
#
#        Start Station ID Start Station Name  Start Station Latitude  \
# ...

# %%
# Identify data type
JC_cleaned_tripdata_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32154 entries, 0 to 35570
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Trip Duration            32154 non-null  int64
#  1   Start Time               32154 non-null  object
#  2   Stop Time                32154 non-null  object
#  3   Start Station ID         32154 non-null  int64
#  4   Start Station Name       32154 non-null  object
#  5   Start Station Latitude   32154 non-null  float64
#  6   Start Station Longitude  32154 non-null  float64
#  7   End Station ID           32154 non-null  int64
#  8   End Station Name         32154 non-null  object
#  9   End Station Latitude     32154 non-null  float64
#  10  End Station Longitude    32154 non-null  float64
#  11  Bike ID                  32154 non-null  int64
#  12  User Type                32154 non-null  object
#  13  Birth Year               32154 non-null  float64
# ...

# %%
# Change birth year data type to int64
JC_cleaned_tripdata_df["Birth Year"] = JC_cleaned_tripdata_df["Birth Year"].astype("int64")
JC_cleaned_tripdata_df
# Out:
#        Trip Duration                Start Time                 Stop Time  \
# 0                669       2016-06-01 00:00:37       2016-06-01 00:11:46
# 1                945       2016-06-01 00:14:54       2016-06-01 00:30:40
# 2                334       2016-06-01 00:34:52       2016-06-01 00:40:26
# 3                473       2016-06-01 00:40:30       2016-06-01 00:48:23
# 4                551       2016-06-01 00:50:06       2016-06-01 00:59:17
# ...              ...                       ...                       ...
# 35566           2476  2021-01-31 20:16:05.4700  2021-01-31 20:57:22.0110
# 35567            147  2021-01-31 21:05:05.2090  2021-01-31 21:07:32.8660
# 35568            660  2021-01-31 21:06:23.5880  2021-01-31 21:17:23.8420
# 35569            384  2021-01-31 21:16:37.8220  2021-01-31 21:23:02.1240
# 35570            356  2021-01-31 23:24:50.8810  2021-01-31 23:30:47.3030
#
#        Start Station ID Start Station Name  Start Station Latitude  \
# ...

# %%
# Identify the user type
JC_cleaned_tripdata_user_df = JC_cleaned_tripdata_df["User Type"].unique().tolist()
JC_cleaned_tripdata_user_df
# Out:
# ['Subscriber', 'Customer']

# %%
# Identify the gender
JC_cleaned_tripdata_gender_df = JC_cleaned_tripdata_df["Gender"].unique().tolist()
JC_cleaned_tripdata_gender_df
# Out:
# [1, 2]

# %%
# Add column Trip ID and set it as index
# Generate a list of index values (e.g., 0, 1, 2)
new_index_values = list(range(len(JC_cleaned_tripdata_df)))

# Assign the list as the index to the DataFrame
JC_cleaned_tripdata_df.index = new_index_values
JC_cleaned_tripdata_df["Trip ID"] = new_index_values
JC_cleaned_tripdata_df.set_index("Trip ID", inplace=True)

# %%
# Review the dataframe
JC_cleaned_tripdata_df
# Out:
#          Trip Duration                Start Time                 Stop Time  \
# Trip ID
# 0                  669       2016-06-01 00:00:37       2016-06-01 00:11:46
# 1                  945       2016-06-01 00:14:54       2016-06-01 00:30:40
# 2                  334       2016-06-01 00:34:52       2016-06-01 00:40:26
# 3                  473       2016-06-01 00:40:30       2016-06-01 00:48:23
# 4                  551       2016-06-01 00:50:06       2016-06-01 00:59:17
# ...                ...                       ...                       ...
# 32149             2476  2021-01-31 20:16:05.4700  2021-01-31 20:57:22.0110
# 32150              147  2021-01-31 21:05:05.2090  2021-01-31 21:07:32.8660
# 32151              660  2021-01-31 21:06:23.5880  2021-01-31 21:17:23.8420
# 32152              384  2021-01-31 21:16:37.8220  2021-01-31 21:23:02.1240
# 32153              356  2021-01-31 23:24:50.8810  2021-01-31 23:30:47.3030
#
# ...

# %%
# Save combined, cleaned csv file
# Exporting JC_cleaned_tripdata_df into csv file
JC_cleaned_tripdata_df.to_csv("Resources/JC_cleaned_tripdata.csv", index = True, header = True)
